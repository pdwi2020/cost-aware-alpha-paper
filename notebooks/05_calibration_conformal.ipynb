# %% [markdown]
# # 05 — Calibration & Conformal Prediction
#
# Split conformal intervals, conformal-leverage position sizing, ECE.

# %%
import sys
sys.path.insert(0, '..')
from src.calibration.conformal import ConformalIntervals
import pandas as pd

# %% [markdown]
# ## 1. Split Conformal Intervals (α=0.10)

# %%
# TODO: fit conformal on 20% of each walk-forward train; compute intervals on test

# %% [markdown]
# ## 2. Coverage Verification

# %%
# TODO: verify empirical coverage ≥ 90%; plot coverage rate by fold

# %% [markdown]
# ## 3. Conformal-Leverage Position Sizing

# %%
# TODO: raw_score = signal / interval_width; normalize to 1x gross; apply 5% cap + 2x hard cap

# %% [markdown]
# ## 4. ECE (Expected Calibration Error)

# %%
# TODO: ECE with 10 bins; before/after conformal; reliability diagram
