# %% [markdown]
# # 03 — FDR & PBO Analysis
#
# Benjamini-Hochberg correction, CSCV Probability of Backtest Overfitting, Deflated Sharpe.

# %%
import sys
sys.path.insert(0, '..')
from src.fdr.bh_correction import benjamini_hochberg
from src.fdr.pbo_cscv import compute_pbo
import yaml

with open('../configs/fdr.yaml') as f:
    fdr_cfg = yaml.safe_load(f)

# %% [markdown]
# ## 1. Feature IC t-statistics

# %%
# TODO: compute IC t-stats for each of 40+ features across 9 walk-forward folds

# %% [markdown]
# ## 2. Benjamini-Hochberg Correction (q=0.05)

# %%
# TODO: apply BH; identify surviving features; plot sorted p-values vs BH threshold

# %% [markdown]
# ## 3. Regime-Conditional FDR (VIX calm/stressed)

# %%
# TODO: split IC by VIX regime; include ALL tests in single BH pool

# %% [markdown]
# ## 4. CSCV — Probability of Backtest Overfitting

# %%
# TODO: run CSCV with S=16 splits; compute PBO for each model; target PBO < 0.30

# %% [markdown]
# ## 5. Deflated Sharpe Ratio

# %%
# TODO: compute DSR for ensemble; report with number of trials adjustment

# %% [markdown]
# ## 6. Bootstrap IC Confidence Intervals

# %%
# TODO: block bootstrap L=21, B=1000; IC distribution per model
