# %% [markdown]
# # 02 — Baseline Models
#
# Walk-forward CV for all 6 models + SHAP feature attribution.

# %%
import sys
sys.path.insert(0, '..')
from src.models.model_suite import ModelSuite
import pandas as pd
import yaml

with open('../configs/models.yaml') as f:
    cfg = yaml.safe_load(f)

# %% [markdown]
# ## 1. Walk-Forward Setup
#
# Expanding window: 3yr warmup, 1yr step, 9 folds (2013–2021).

# %%
# TODO: define walk-forward fold dates; verify no leakage (train_end < test_start)

# %% [markdown]
# ## 2. Fit All Models (Track A)

# %%
# TODO: run ModelSuite.fit_all() on walk-forward splits; record IC per fold

# %% [markdown]
# ## 3. Fit All Models (Track B)

# %%
# TODO: repeat for Track B (raw forward returns)

# %% [markdown]
# ## 4. IC Summary Table

# %%
# TODO: table: model × fold IC; mean, std, IR (IC/std), t-stat

# %% [markdown]
# ## 5. SHAP Feature Importance

# %%
# TODO: compute SHAP for XGB + LGBM; plot top-20 mean |SHAP| bar chart

# %% [markdown]
# ## 6. Ensemble Model

# %%
# TODO: IC-weighted ensemble of XGB + LGBM + Logistic; compare vs individual
