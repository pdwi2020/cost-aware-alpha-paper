# %% [markdown]
# # 06 — Regime Analysis
#
# VIX-regime conditional performance and Polymarket robustness check.

# %%
import sys
sys.path.insert(0, '..')
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. VIX Regime Split (calm ≤20, stressed >20)

# %%
# TODO: load VIX; split dates into calm/stressed; compute IC per regime

# %% [markdown]
# ## 2. Regime-Conditional Sharpe and IC

# %%
# TODO: table: model × regime → IC, Sharpe, # trading days

# %% [markdown]
# ## 3. Polymarket Feature Robustness

# %%
# TODO: re-run ensemble with polymarket_features added; compare IC delta vs baseline
