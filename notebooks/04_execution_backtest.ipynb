# %% [markdown]
# # 04 — Execution Backtest
#
# Almgren-Chriss execution model, 2D cost surface, capacity analysis.

# %%
import sys
sys.path.insert(0, '..')
from src.backtest.almgren_chriss import compute_impact_cost
from src.backtest.portfolio import run_backtest
import yaml

with open('../configs/backtest.yaml') as f:
    bt_cfg = yaml.safe_load(f)

# %% [markdown]
# ## 1. Execution Cost Model Validation

# %%
# TODO: verify impact_cost formula; sanity check vs Frazzini et al. empirical estimates

# %% [markdown]
# ## 2. Backtest — Gross vs Net P&L

# %%
# TODO: run_backtest() with base params (spread=3bps, impact=0.10); plot gross vs net Sharpe

# %% [markdown]
# ## 3. Turnover-Frequency Surface

# %%
# TODO: rebalancing freq ∈ {1, 5, 21} × turnover lambda ∈ {0, 0.001, 0.005, 0.01, 0.05}

# %% [markdown]
# ## 4. 2D Cost Sensitivity Surface

# %%
# TODO: spread_bps ∈ {1,3,5,7,10} × impact_coeff ∈ {0.05,0.10,0.15,0.20}; heatmap of net Sharpe

# %% [markdown]
# ## 5. Capacity Curve

# %%
# TODO: scale impact_coeff ∝ sqrt(AUM / 100M); plot Sharpe vs AUM; find break-even AUM
